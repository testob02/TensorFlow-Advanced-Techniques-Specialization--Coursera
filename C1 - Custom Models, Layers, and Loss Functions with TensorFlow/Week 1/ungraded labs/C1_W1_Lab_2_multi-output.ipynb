# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = 'ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 8)]          0           []
#
#  dense (Dense)                  (None, 128)          1152        ['input_1[0][0]']
#
#  dense_1 (Dense)                (None, 128)          16512       ['dense[0][0]']
#
#  dense_2 (Dense)                (None, 64)           8256        ['dense_1[0][0]']
#
#  y1_output (Dense)              (None, 1)            129         ['dense_1[0][0]']
#
#  y2_output (Dense)              (None, 1)            65          ['dense_2[0][0]']
#
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})
# Out:
# c:\Users\User\miniconda3\envs\tf\lib\site-packages\keras\optimizers\optimizer_v2\gradient_descent.py:111: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Epoch 1/500
# 62/62 [==============================] - 14s 53ms/step - loss: 230.0985 - y1_output_loss: 109.4946 - y2_output_loss: 120.6040 - y1_output_root_mean_squared_error: 10.4640 - y2_output_root_mean_squared_error: 10.9820 - val_loss: 222.8453 - val_y1_output_loss: 39.1777 - val_y2_output_loss: 183.6676 - val_y1_output_root_mean_squared_error: 6.2592 - val_y2_output_root_mean_squared_error: 13.5524
# Epoch 2/500
# 62/62 [==============================] - 3s 41ms/step - loss: 46.9682 - y1_output_loss: 15.6826 - y2_output_loss: 31.2856 - y1_output_root_mean_squared_error: 3.9601 - y2_output_root_mean_squared_error: 5.5934 - val_loss: 25.0986 - val_y1_output_loss: 10.8773 - val_y2_output_loss: 14.2213 - val_y1_output_root_mean_squared_error: 3.2981 - val_y2_output_root_mean_squared_error: 3.7711
# Epoch 3/500
# 62/62 [==============================] - 1s 10ms/step - loss: 25.2749 - y1_output_loss: 9.9536 - y2_output_loss: 15.3213 - y1_output_root_mean_squared_error: 3.1549 - y2_output_root_mean_squared_error: 3.9142 - val_loss: 206.8910 - val_y1_output_loss: 27.0719 - val_y2_output_loss: 179.8191 - val_y1_output_root_mean_squared_error: 5.2031 - val_y2_output_root_mean_squared_error: 13.4097
# Epoch 4/500
# 62/62 [==============================] - 2s 39ms/step - loss: 33.0412 - y1_output_loss: 10.1321 - y2_output_loss: 22.9092 - y1_output_root_mean_squared_error: 3.1831 - y2_output_root_mean_squared_error: 4.7864 - val_loss: 25.0558 - val_y1_output_loss: 9.5189 - val_y2_output_loss: 15.5369 - val_y1_output_root_mean_squared_error: 3.0853 - val_y2_output_root_mean_squared_error: 3.9417
# Epoch 5/500
# 62/62 [==============================] - 2s 39ms/step - loss: 25.0617 - y1_output_loss: 9.6221 - y2_output_loss: 15.4397 - y1_output_root_mean_squared_error: 3.1019 - y2_output_root_mean_squared_error: 3.9293 - val_loss: 23.7144 - val_y1_output_loss: 9.0341 - val_y2_output_loss: 14.6802 - val_y1_output_root_mean_squared_error: 3.0057 - val_y2_output_root_mean_squared_error: 3.8315
# Epoch 6/500
# 62/62 [==============================] - 1s 11ms/step - loss: 21.8764 - y1_output_loss: 8.8157 - y2_output_loss: 13.0607 - y1_output_root_mean_squared_error: 2.9691 - y2_output_root_mean_squared_error: 3.6140 - val_loss: 18.7171 - val_y1_output_loss: 7.6816 - val_y2_output_loss: 11.0355 - val_y1_output_root_mean_squared_error: 2.7716 - val_y2_output_root_mean_squared_error: 3.3220
# Epoch 7/500
# 62/62 [==============================] - 3s 49ms/step - loss: 23.0640 - y1_output_loss: 8.9159 - y2_output_loss: 14.1481 - y1_output_root_mean_squared_error: 2.9860 - y2_output_root_mean_squared_error: 3.7614 - val_loss: 20.3629 - val_y1_output_loss: 8.1936 - val_y2_output_loss: 12.1693 - val_y1_output_root_mean_squared_error: 2.8624 - val_y2_output_root_mean_squared_error: 3.4884
# Epoch 8/500
# 62/62 [==============================] - 3s 44ms/step - loss: 25.1342 - y1_output_loss: 9.0524 - y2_output_loss: 16.0818 - y1_output_root_mean_squared_error: 3.0087 - y2_output_root_mean_squared_error: 4.0102 - val_loss: 19.3766 - val_y1_output_loss: 8.3165 - val_y2_output_loss: 11.0602 - val_y1_output_root_mean_squared_error: 2.8838 - val_y2_output_root_mean_squared_error: 3.3257
# Epoch 9/500
# 62/62 [==============================] - 3s 47ms/step - loss: 23.4673 - y1_output_loss: 8.9013 - y2_output_loss: 14.5660 - y1_output_root_mean_squared_error: 2.9835 - y2_output_root_mean_squared_error: 3.8165 - val_loss: 19.5072 - val_y1_output_loss: 8.5909 - val_y2_output_loss: 10.9163 - val_y1_output_root_mean_squared_error: 2.9310 - val_y2_output_root_mean_squared_error: 3.3040
# Epoch 10/500
# 62/62 [==============================] - 4s 63ms/step - loss: 21.1907 - y1_output_loss: 8.1675 - y2_output_loss: 13.0231 - y1_output_root_mean_squared_error: 2.8579 - y2_output_root_mean_squared_error: 3.6088 - val_loss: 18.1956 - val_y1_output_loss: 7.4691 - val_y2_output_loss: 10.7265 - val_y1_output_root_mean_squared_error: 2.7330 - val_y2_output_root_mean_squared_error: 3.2751
# Epoch 11/500
# 62/62 [==============================] - 3s 47ms/step - loss: 21.9469 - y1_output_loss: 8.3970 - y2_output_loss: 13.5499 - y1_output_root_mean_squared_error: 2.8977 - y2_output_root_mean_squared_error: 3.6810 - val_loss: 27.8996 - val_y1_output_loss: 8.9147 - val_y2_output_loss: 18.9850 - val_y1_output_root_mean_squared_error: 2.9857 - val_y2_output_root_mean_squared_error: 4.3572
# Epoch 12/500
# 62/62 [==============================] - 3s 42ms/step - loss: 21.6221 - y1_output_loss: 8.5013 - y2_output_loss: 13.1209 - y1_output_root_mean_squared_error: 2.9157 - y2_output_root_mean_squared_error: 3.6223 - val_loss: 17.8008 - val_y1_output_loss: 7.4341 - val_y2_output_loss: 10.3667 - val_y1_output_root_mean_squared_error: 2.7265 - val_y2_output_root_mean_squared_error: 3.2197
# Epoch 13/500
# 62/62 [==============================] - 1s 16ms/step - loss: 19.4024 - y1_output_loss: 7.6409 - y2_output_loss: 11.7615 - y1_output_root_mean_squared_error: 2.7642 - y2_output_root_mean_squared_error: 3.4295 - val_loss: 17.2896 - val_y1_output_loss: 7.2034 - val_y2_output_loss: 10.0862 - val_y1_output_root_mean_squared_error: 2.6839 - val_y2_output_root_mean_squared_error: 3.1759
# Epoch 14/500
# 62/62 [==============================] - 3s 43ms/step - loss: 19.7613 - y1_output_loss: 7.6434 - y2_output_loss: 12.1179 - y1_output_root_mean_squared_error: 2.7647 - y2_output_root_mean_squared_error: 3.4811 - val_loss: 18.0011 - val_y1_output_loss: 7.0011 - val_y2_output_loss: 10.9999 - val_y1_output_root_mean_squared_error: 2.6460 - val_y2_output_root_mean_squared_error: 3.3166
# Epoch 15/500
# 62/62 [==============================] - 3s 47ms/step - loss: 18.5786 - y1_output_loss: 7.3311 - y2_output_loss: 11.2474 - y1_output_root_mean_squared_error: 2.7076 - y2_output_root_mean_squared_error: 3.3537 - val_loss: 16.3882 - val_y1_output_loss: 6.4138 - val_y2_output_loss: 9.9743 - val_y1_output_root_mean_squared_error: 2.5326 - val_y2_output_root_mean_squared_error: 3.1582
# Epoch 16/500
# 62/62 [==============================] - 3s 54ms/step - loss: 19.6268 - y1_output_loss: 7.7272 - y2_output_loss: 11.8996 - y1_output_root_mean_squared_error: 2.7798 - y2_output_root_mean_squared_error: 3.4496 - val_loss: 17.1809 - val_y1_output_loss: 6.9039 - val_y2_output_loss: 10.2770 - val_y1_output_root_mean_squared_error: 2.6275 - val_y2_output_root_mean_squared_error: 3.2058
# Epoch 17/500
# 62/62 [==============================] - 3s 53ms/step - loss: 16.1185 - y1_output_loss: 6.4414 - y2_output_loss: 9.6771 - y1_output_root_mean_squared_error: 2.5380 - y2_output_root_mean_squared_error: 3.1108 - val_loss: 32.7501 - val_y1_output_loss: 8.4486 - val_y2_output_loss: 24.3016 - val_y1_output_root_mean_squared_error: 2.9066 - val_y2_output_root_mean_squared_error: 4.9297
# Epoch 18/500
# 62/62 [==============================] - 3s 53ms/step - loss: 21.7256 - y1_output_loss: 7.7495 - y2_output_loss: 13.9762 - y1_output_root_mean_squared_error: 2.7838 - y2_output_root_mean_squared_error: 3.7385 - val_loss: 16.2852 - val_y1_output_loss: 5.6216 - val_y2_output_loss: 10.6637 - val_y1_output_root_mean_squared_error: 2.3710 - val_y2_output_root_mean_squared_error: 3.2655
# Epoch 19/500
# 62/62 [==============================] - 3s 43ms/step - loss: 15.4521 - y1_output_loss: 6.1733 - y2_output_loss: 9.2787 - y1_output_root_mean_squared_error: 2.4846 - y2_output_root_mean_squared_error: 3.0461 - val_loss: 26.5745 - val_y1_output_loss: 8.6865 - val_y2_output_loss: 17.8880 - val_y1_output_root_mean_squared_error: 2.9473 - val_y2_output_root_mean_squared_error: 4.2294
# Epoch 20/500
# 62/62 [==============================] - 3s 44ms/step - loss: 14.9833 - y1_output_loss: 6.0615 - y2_output_loss: 8.9218 - y1_output_root_mean_squared_error: 2.4620 - y2_output_root_mean_squared_error: 2.9869 - val_loss: 16.6124 - val_y1_output_loss: 5.9589 - val_y2_output_loss: 10.6535 - val_y1_output_root_mean_squared_error: 2.4411 - val_y2_output_root_mean_squared_error: 3.2640
# Epoch 21/500
# 62/62 [==============================] - 3s 46ms/step - loss: 22.0570 - y1_output_loss: 7.1108 - y2_output_loss: 14.9462 - y1_output_root_mean_squared_error: 2.6666 - y2_output_root_mean_squared_error: 3.8660 - val_loss: 15.0980 - val_y1_output_loss: 5.2268 - val_y2_output_loss: 9.8713 - val_y1_output_root_mean_squared_error: 2.2862 - val_y2_output_root_mean_squared_error: 3.1419
# Epoch 22/500
# 62/62 [==============================] - 3s 44ms/step - loss: 14.3363 - y1_output_loss: 5.4381 - y2_output_loss: 8.8982 - y1_output_root_mean_squared_error: 2.3320 - y2_output_root_mean_squared_error: 2.9830 - val_loss: 23.4556 - val_y1_output_loss: 7.1916 - val_y2_output_loss: 16.2640 - val_y1_output_root_mean_squared_error: 2.6817 - val_y2_output_root_mean_squared_error: 4.0329
# Epoch 23/500
# 62/62 [==============================] - 1s 13ms/step - loss: 14.9998 - y1_output_loss: 5.9167 - y2_output_loss: 9.0830 - y1_output_root_mean_squared_error: 2.4324 - y2_output_root_mean_squared_error: 3.0138 - val_loss: 13.5736 - val_y1_output_loss: 5.4797 - val_y2_output_loss: 8.0939 - val_y1_output_root_mean_squared_error: 2.3409 - val_y2_output_root_mean_squared_error: 2.8450
# Epoch 24/500
# 62/62 [==============================] - 3s 43ms/step - loss: 12.3976 - y1_output_loss: 5.2145 - y2_output_loss: 7.1831 - y1_output_root_mean_squared_error: 2.2835 - y2_output_root_mean_squared_error: 2.6801 - val_loss: 12.4368 - val_y1_output_loss: 4.6826 - val_y2_output_loss: 7.7542 - val_y1_output_root_mean_squared_error: 2.1639 - val_y2_output_root_mean_squared_error: 2.7846
# Epoch 25/500
# 62/62 [==============================] - 3s 49ms/step - loss: 13.4964 - y1_output_loss: 5.1265 - y2_output_loss: 8.3699 - y1_output_root_mean_squared_error: 2.2642 - y2_output_root_mean_squared_error: 2.8931 - val_loss: 12.0740 - val_y1_output_loss: 4.7679 - val_y2_output_loss: 7.3061 - val_y1_output_root_mean_squared_error: 2.1836 - val_y2_output_root_mean_squared_error: 2.7030
# Epoch 26/500
# 62/62 [==============================] - 3s 54ms/step - loss: 12.9337 - y1_output_loss: 4.8737 - y2_output_loss: 8.0600 - y1_output_root_mean_squared_error: 2.2077 - y2_output_root_mean_squared_error: 2.8390 - val_loss: 10.8957 - val_y1_output_loss: 3.9323 - val_y2_output_loss: 6.9634 - val_y1_output_root_mean_squared_error: 1.9830 - val_y2_output_root_mean_squared_error: 2.6388
# Epoch 27/500
# 62/62 [==============================] - 3s 55ms/step - loss: 13.8304 - y1_output_loss: 4.9156 - y2_output_loss: 8.9148 - y1_output_root_mean_squared_error: 2.2171 - y2_output_root_mean_squared_error: 2.9858 - val_loss: 14.8450 - val_y1_output_loss: 5.4555 - val_y2_output_loss: 9.3895 - val_y1_output_root_mean_squared_error: 2.3357 - val_y2_output_root_mean_squared_error: 3.0642
# Epoch 28/500
# 62/62 [==============================] - 3s 49ms/step - loss: 13.1650 - y1_output_loss: 4.6927 - y2_output_loss: 8.4724 - y1_output_root_mean_squared_error: 2.1663 - y2_output_root_mean_squared_error: 2.9107 - val_loss: 28.6081 - val_y1_output_loss: 10.8348 - val_y2_output_loss: 17.7733 - val_y1_output_root_mean_squared_error: 3.2916 - val_y2_output_root_mean_squared_error: 4.2158
# Epoch 29/500
# 62/62 [==============================] - 3s 50ms/step - loss: 13.2064 - y1_output_loss: 4.7931 - y2_output_loss: 8.4134 - y1_output_root_mean_squared_error: 2.1893 - y2_output_root_mean_squared_error: 2.9006 - val_loss: 10.4800 - val_y1_output_loss: 3.5626 - val_y2_output_loss: 6.9174 - val_y1_output_root_mean_squared_error: 1.8875 - val_y2_output_root_mean_squared_error: 2.6301
# Epoch 30/500
# 62/62 [==============================] - 3s 54ms/step - loss: 11.1654 - y1_output_loss: 4.1768 - y2_output_loss: 6.9886 - y1_output_root_mean_squared_error: 2.0437 - y2_output_root_mean_squared_error: 2.6436 - val_loss: 10.1905 - val_y1_output_loss: 3.9627 - val_y2_output_loss: 6.2278 - val_y1_output_root_mean_squared_error: 1.9907 - val_y2_output_root_mean_squared_error: 2.4955
# Epoch 31/500
# 62/62 [==============================] - 3s 47ms/step - loss: 9.5531 - y1_output_loss: 3.5444 - y2_output_loss: 6.0087 - y1_output_root_mean_squared_error: 1.8827 - y2_output_root_mean_squared_error: 2.4513 - val_loss: 25.8904 - val_y1_output_loss: 8.0231 - val_y2_output_loss: 17.8674 - val_y1_output_root_mean_squared_error: 2.8325 - val_y2_output_root_mean_squared_error: 4.2270
# Epoch 32/500
# 62/62 [==============================] - 1s 17ms/step - loss: 13.0035 - y1_output_loss: 4.4785 - y2_output_loss: 8.5250 - y1_output_root_mean_squared_error: 2.1162 - y2_output_root_mean_squared_error: 2.9198 - val_loss: 17.3960 - val_y1_output_loss: 3.7709 - val_y2_output_loss: 13.6250 - val_y1_output_root_mean_squared_error: 1.9419 - val_y2_output_root_mean_squared_error: 3.6912
# Epoch 33/500
# 62/62 [==============================] - 3s 53ms/step - loss: 10.1008 - y1_output_loss: 3.7405 - y2_output_loss: 6.3603 - y1_output_root_mean_squared_error: 1.9340 - y2_output_root_mean_squared_error: 2.5220 - val_loss: 20.7903 - val_y1_output_loss: 4.7220 - val_y2_output_loss: 16.0683 - val_y1_output_root_mean_squared_error: 2.1730 - val_y2_output_root_mean_squared_error: 4.0085
# Epoch 34/500
# 62/62 [==============================] - 3s 49ms/step - loss: 8.3453 - y1_output_loss: 3.2465 - y2_output_loss: 5.0988 - y1_output_root_mean_squared_error: 1.8018 - y2_output_root_mean_squared_error: 2.2581 - val_loss: 9.5693 - val_y1_output_loss: 3.5083 - val_y2_output_loss: 6.0611 - val_y1_output_root_mean_squared_error: 1.8730 - val_y2_output_root_mean_squared_error: 2.4619
# Epoch 35/500
# 62/62 [==============================] - 1s 13ms/step - loss: 9.2273 - y1_output_loss: 3.2758 - y2_output_loss: 5.9516 - y1_output_root_mean_squared_error: 1.8099 - y2_output_root_mean_squared_error: 2.4396 - val_loss: 21.0244 - val_y1_output_loss: 7.2183 - val_y2_output_loss: 13.8062 - val_y1_output_root_mean_squared_error: 2.6867 - val_y2_output_root_mean_squared_error: 3.7157
# Epoch 36/500
# 62/62 [==============================] - 5s 87ms/step - loss: 10.4457 - y1_output_loss: 3.6348 - y2_output_loss: 6.8109 - y1_output_root_mean_squared_error: 1.9065 - y2_output_root_mean_squared_error: 2.6098 - val_loss: 13.3984 - val_y1_output_loss: 2.7483 - val_y2_output_loss: 10.6501 - val_y1_output_root_mean_squared_error: 1.6578 - val_y2_output_root_mean_squared_error: 3.2635
# Epoch 37/500
# 62/62 [==============================] - 3s 51ms/step - loss: 9.0130 - y1_output_loss: 3.1669 - y2_output_loss: 5.8461 - y1_output_root_mean_squared_error: 1.7796 - y2_output_root_mean_squared_error: 2.4179 - val_loss: 10.8947 - val_y1_output_loss: 4.0874 - val_y2_output_loss: 6.8074 - val_y1_output_root_mean_squared_error: 2.0217 - val_y2_output_root_mean_squared_error: 2.6091
# Epoch 38/500
# 62/62 [==============================] - 1s 13ms/step - loss: 8.5905 - y1_output_loss: 3.1017 - y2_output_loss: 5.4889 - y1_output_root_mean_squared_error: 1.7612 - y2_output_root_mean_squared_error: 2.3428 - val_loss: 41.8949 - val_y1_output_loss: 12.6419 - val_y2_output_loss: 29.2530 - val_y1_output_root_mean_squared_error: 3.5555 - val_y2_output_root_mean_squared_error: 5.4086
# Epoch 39/500
# 62/62 [==============================] - 3s 42ms/step - loss: 8.5932 - y1_output_loss: 2.9278 - y2_output_loss: 5.6655 - y1_output_root_mean_squared_error: 1.7111 - y2_output_root_mean_squared_error: 2.3802 - val_loss: 37.0861 - val_y1_output_loss: 12.4591 - val_y2_output_loss: 24.6270 - val_y1_output_root_mean_squared_error: 3.5297 - val_y2_output_root_mean_squared_error: 4.9626
# Epoch 40/500
# 62/62 [==============================] - 2s 40ms/step - loss: 9.4724 - y1_output_loss: 3.1869 - y2_output_loss: 6.2855 - y1_output_root_mean_squared_error: 1.7852 - y2_output_root_mean_squared_error: 2.5071 - val_loss: 7.6852 - val_y1_output_loss: 2.3610 - val_y2_output_loss: 5.3242 - val_y1_output_root_mean_squared_error: 1.5365 - val_y2_output_root_mean_squared_error: 2.3074
# Epoch 41/500
# 62/62 [==============================] - 2s 41ms/step - loss: 9.1024 - y1_output_loss: 2.8149 - y2_output_loss: 6.2875 - y1_output_root_mean_squared_error: 1.6778 - y2_output_root_mean_squared_error: 2.5075 - val_loss: 8.8655 - val_y1_output_loss: 2.7824 - val_y2_output_loss: 6.0831 - val_y1_output_root_mean_squared_error: 1.6681 - val_y2_output_root_mean_squared_error: 2.4664
# Epoch 42/500
# 62/62 [==============================] - 1s 11ms/step - loss: 7.6214 - y1_output_loss: 2.5466 - y2_output_loss: 5.0748 - y1_output_root_mean_squared_error: 1.5958 - y2_output_root_mean_squared_error: 2.2527 - val_loss: 11.4164 - val_y1_output_loss: 2.2483 - val_y2_output_loss: 9.1681 - val_y1_output_root_mean_squared_error: 1.4994 - val_y2_output_root_mean_squared_error: 3.0279
# Epoch 43/500
# 62/62 [==============================] - 3s 46ms/step - loss: 8.0295 - y1_output_loss: 2.7093 - y2_output_loss: 5.3201 - y1_output_root_mean_squared_error: 1.6460 - y2_output_root_mean_squared_error: 2.3065 - val_loss: 10.0211 - val_y1_output_loss: 2.5818 - val_y2_output_loss: 7.4393 - val_y1_output_root_mean_squared_error: 1.6068 - val_y2_output_root_mean_squared_error: 2.7275
# Epoch 44/500
# 62/62 [==============================] - 3s 47ms/step - loss: 9.2064 - y1_output_loss: 2.8734 - y2_output_loss: 6.3330 - y1_output_root_mean_squared_error: 1.6951 - y2_output_root_mean_squared_error: 2.5166 - val_loss: 33.6281 - val_y1_output_loss: 12.2792 - val_y2_output_loss: 21.3489 - val_y1_output_root_mean_squared_error: 3.5042 - val_y2_output_root_mean_squared_error: 4.6205
# Epoch 45/500
# 62/62 [==============================] - 3s 53ms/step - loss: 8.2695 - y1_output_loss: 2.5349 - y2_output_loss: 5.7346 - y1_output_root_mean_squared_error: 1.5921 - y2_output_root_mean_squared_error: 2.3947 - val_loss: 6.7958 - val_y1_output_loss: 1.8191 - val_y2_output_loss: 4.9767 - val_y1_output_root_mean_squared_error: 1.3487 - val_y2_output_root_mean_squared_error: 2.2309
# Epoch 46/500
# 62/62 [==============================] - 3s 54ms/step - loss: 7.6049 - y1_output_loss: 2.4028 - y2_output_loss: 5.2021 - y1_output_root_mean_squared_error: 1.5501 - y2_output_root_mean_squared_error: 2.2808 - val_loss: 15.4512 - val_y1_output_loss: 3.6793 - val_y2_output_loss: 11.7719 - val_y1_output_root_mean_squared_error: 1.9182 - val_y2_output_root_mean_squared_error: 3.4310
# Epoch 47/500
# 62/62 [==============================] - 3s 51ms/step - loss: 8.4471 - y1_output_loss: 2.7706 - y2_output_loss: 5.6764 - y1_output_root_mean_squared_error: 1.6645 - y2_output_root_mean_squared_error: 2.3825 - val_loss: 20.3555 - val_y1_output_loss: 5.7560 - val_y2_output_loss: 14.5995 - val_y1_output_root_mean_squared_error: 2.3992 - val_y2_output_root_mean_squared_error: 3.8209
# Epoch 48/500
# 62/62 [==============================] - 3s 45ms/step - loss: 9.4202 - y1_output_loss: 2.7392 - y2_output_loss: 6.6810 - y1_output_root_mean_squared_error: 1.6551 - y2_output_root_mean_squared_error: 2.5848 - val_loss: 7.5292 - val_y1_output_loss: 2.0046 - val_y2_output_loss: 5.5246 - val_y1_output_root_mean_squared_error: 1.4159 - val_y2_output_root_mean_squared_error: 2.3504
# Epoch 49/500
# 62/62 [==============================] - 3s 41ms/step - loss: 6.3483 - y1_output_loss: 2.2039 - y2_output_loss: 4.1443 - y1_output_root_mean_squared_error: 1.4846 - y2_output_root_mean_squared_error: 2.0358 - val_loss: 8.3531 - val_y1_output_loss: 2.5145 - val_y2_output_loss: 5.8386 - val_y1_output_root_mean_squared_error: 1.5857 - val_y2_output_root_mean_squared_error: 2.4163
# Epoch 50/500
# 62/62 [==============================] - 3s 44ms/step - loss: 6.3354 - y1_output_loss: 2.0233 - y2_output_loss: 4.3121 - y1_output_root_mean_squared_error: 1.4224 - y2_output_root_mean_squared_error: 2.0766 - val_loss: 9.9056 - val_y1_output_loss: 2.3728 - val_y2_output_loss: 7.5329 - val_y1_output_root_mean_squared_error: 1.5404 - val_y2_output_root_mean_squared_error: 2.7446
# Epoch 51/500
# 62/62 [==============================] - 3s 49ms/step - loss: 7.3364 - y1_output_loss: 2.2015 - y2_output_loss: 5.1349 - y1_output_root_mean_squared_error: 1.4837 - y2_output_root_mean_squared_error: 2.2660 - val_loss: 9.9124 - val_y1_output_loss: 2.3534 - val_y2_output_loss: 7.5590 - val_y1_output_root_mean_squared_error: 1.5341 - val_y2_output_root_mean_squared_error: 2.7494
# Epoch 52/500
# 62/62 [==============================] - 1s 16ms/step - loss: 6.2818 - y1_output_loss: 2.0072 - y2_output_loss: 4.2746 - y1_output_root_mean_squared_error: 1.4168 - y2_output_root_mean_squared_error: 2.0675 - val_loss: 8.6678 - val_y1_output_loss: 2.0380 - val_y2_output_loss: 6.6298 - val_y1_output_root_mean_squared_error: 1.4276 - val_y2_output_root_mean_squared_error: 2.5748
# Epoch 53/500
# 62/62 [==============================] - 3s 51ms/step - loss: 6.4059 - y1_output_loss: 2.0069 - y2_output_loss: 4.3990 - y1_output_root_mean_squared_error: 1.4166 - y2_output_root_mean_squared_error: 2.0974 - val_loss: 8.6320 - val_y1_output_loss: 1.5920 - val_y2_output_loss: 7.0400 - val_y1_output_root_mean_squared_error: 1.2617 - val_y2_output_root_mean_squared_error: 2.6533
# Epoch 54/500
# 62/62 [==============================] - 3s 52ms/step - loss: 6.8712 - y1_output_loss: 1.9982 - y2_output_loss: 4.8731 - y1_output_root_mean_squared_error: 1.4136 - y2_output_root_mean_squared_error: 2.2075 - val_loss: 5.8375 - val_y1_output_loss: 1.3695 - val_y2_output_loss: 4.4680 - val_y1_output_root_mean_squared_error: 1.1703 - val_y2_output_root_mean_squared_error: 2.1138
# Epoch 55/500
# 62/62 [==============================] - 3s 49ms/step - loss: 7.0615 - y1_output_loss: 2.0627 - y2_output_loss: 4.9988 - y1_output_root_mean_squared_error: 1.4362 - y2_output_root_mean_squared_error: 2.2358 - val_loss: 8.3092 - val_y1_output_loss: 1.4483 - val_y2_output_loss: 6.8609 - val_y1_output_root_mean_squared_error: 1.2035 - val_y2_output_root_mean_squared_error: 2.6193
# Epoch 56/500
# 62/62 [==============================] - 3s 52ms/step - loss: 5.0652 - y1_output_loss: 1.6079 - y2_output_loss: 3.4574 - y1_output_root_mean_squared_error: 1.2680 - y2_output_root_mean_squared_error: 1.8594 - val_loss: 5.8271 - val_y1_output_loss: 1.5569 - val_y2_output_loss: 4.2702 - val_y1_output_root_mean_squared_error: 1.2478 - val_y2_output_root_mean_squared_error: 2.0664
# Epoch 57/500
# 62/62 [==============================] - 3s 55ms/step - loss: 5.5360 - y1_output_loss: 1.6071 - y2_output_loss: 3.9289 - y1_output_root_mean_squared_error: 1.2677 - y2_output_root_mean_squared_error: 1.9821 - val_loss: 9.5546 - val_y1_output_loss: 2.8176 - val_y2_output_loss: 6.7370 - val_y1_output_root_mean_squared_error: 1.6786 - val_y2_output_root_mean_squared_error: 2.5956
# Epoch 58/500
# 62/62 [==============================] - 3s 49ms/step - loss: 6.2772 - y1_output_loss: 1.8883 - y2_output_loss: 4.3889 - y1_output_root_mean_squared_error: 1.3741 - y2_output_root_mean_squared_error: 2.0950 - val_loss: 5.3648 - val_y1_output_loss: 1.1954 - val_y2_output_loss: 4.1694 - val_y1_output_root_mean_squared_error: 1.0933 - val_y2_output_root_mean_squared_error: 2.0419
# Epoch 59/500
# 62/62 [==============================] - 3s 42ms/step - loss: 5.5394 - y1_output_loss: 1.4325 - y2_output_loss: 4.1069 - y1_output_root_mean_squared_error: 1.1969 - y2_output_root_mean_squared_error: 2.0265 - val_loss: 5.4112 - val_y1_output_loss: 1.1804 - val_y2_output_loss: 4.2308 - val_y1_output_root_mean_squared_error: 1.0865 - val_y2_output_root_mean_squared_error: 2.0569
# Epoch 60/500
# 62/62 [==============================] - 1s 12ms/step - loss: 4.8190 - y1_output_loss: 1.4449 - y2_output_loss: 3.3741 - y1_output_root_mean_squared_error: 1.2020 - y2_output_root_mean_squared_error: 1.8369 - val_loss: 22.2749 - val_y1_output_loss: 7.1762 - val_y2_output_loss: 15.0987 - val_y1_output_root_mean_squared_error: 2.6788 - val_y2_output_root_mean_squared_error: 3.8857
# Epoch 61/500
# 62/62 [==============================] - 3s 43ms/step - loss: 6.0094 - y1_output_loss: 1.9332 - y2_output_loss: 4.0762 - y1_output_root_mean_squared_error: 1.3904 - y2_output_root_mean_squared_error: 2.0190 - val_loss: 10.0088 - val_y1_output_loss: 1.9906 - val_y2_output_loss: 8.0182 - val_y1_output_root_mean_squared_error: 1.4109 - val_y2_output_root_mean_squared_error: 2.8316
# Epoch 62/500
# 62/62 [==============================] - 3s 43ms/step - loss: 4.7309 - y1_output_loss: 1.3578 - y2_output_loss: 3.3731 - y1_output_root_mean_squared_error: 1.1652 - y2_output_root_mean_squared_error: 1.8366 - val_loss: 8.3861 - val_y1_output_loss: 1.6835 - val_y2_output_loss: 6.7026 - val_y1_output_root_mean_squared_error: 1.2975 - val_y2_output_root_mean_squared_error: 2.5889
# Epoch 63/500
# 62/62 [==============================] - 3s 47ms/step - loss: 4.7887 - y1_output_loss: 1.4996 - y2_output_loss: 3.2891 - y1_output_root_mean_squared_error: 1.2246 - y2_output_root_mean_squared_error: 1.8136 - val_loss: 17.4242 - val_y1_output_loss: 4.5255 - val_y2_output_loss: 12.8986 - val_y1_output_root_mean_squared_error: 2.1273 - val_y2_output_root_mean_squared_error: 3.5915
# Epoch 64/500
# 62/62 [==============================] - 3s 48ms/step - loss: 5.7573 - y1_output_loss: 1.7777 - y2_output_loss: 3.9795 - y1_output_root_mean_squared_error: 1.3333 - y2_output_root_mean_squared_error: 1.9949 - val_loss: 10.9524 - val_y1_output_loss: 3.7530 - val_y2_output_loss: 7.1994 - val_y1_output_root_mean_squared_error: 1.9373 - val_y2_output_root_mean_squared_error: 2.6832
# Epoch 65/500
# 62/62 [==============================] - 3s 46ms/step - loss: 5.1837 - y1_output_loss: 1.5093 - y2_output_loss: 3.6744 - y1_output_root_mean_squared_error: 1.2285 - y2_output_root_mean_squared_error: 1.9169 - val_loss: 8.5687 - val_y1_output_loss: 2.6226 - val_y2_output_loss: 5.9462 - val_y1_output_root_mean_squared_error: 1.6194 - val_y2_output_root_mean_squared_error: 2.4385
# Epoch 66/500
# 62/62 [==============================] - 1s 14ms/step - loss: 6.7342 - y1_output_loss: 2.0436 - y2_output_loss: 4.6905 - y1_output_root_mean_squared_error: 1.4296 - y2_output_root_mean_squared_error: 2.1658 - val_loss: 13.1140 - val_y1_output_loss: 3.1476 - val_y2_output_loss: 9.9664 - val_y1_output_root_mean_squared_error: 1.7741 - val_y2_output_root_mean_squared_error: 3.1570
# Epoch 67/500
# 62/62 [==============================] - 3s 44ms/step - loss: 7.7377 - y1_output_loss: 2.2064 - y2_output_loss: 5.5313 - y1_output_root_mean_squared_error: 1.4854 - y2_output_root_mean_squared_error: 2.3519 - val_loss: 5.1599 - val_y1_output_loss: 1.2872 - val_y2_output_loss: 3.8726 - val_y1_output_root_mean_squared_error: 1.1346 - val_y2_output_root_mean_squared_error: 1.9679
# Epoch 68/500
# 62/62 [==============================] - 3s 44ms/step - loss: 5.1405 - y1_output_loss: 1.5254 - y2_output_loss: 3.6151 - y1_output_root_mean_squared_error: 1.2351 - y2_output_root_mean_squared_error: 1.9013 - val_loss: 5.3778 - val_y1_output_loss: 1.2200 - val_y2_output_loss: 4.1578 - val_y1_output_root_mean_squared_error: 1.1046 - val_y2_output_root_mean_squared_error: 2.0391
# Epoch 69/500
# 62/62 [==============================] - 1s 11ms/step - loss: 4.7939 - y1_output_loss: 1.3325 - y2_output_loss: 3.4614 - y1_output_root_mean_squared_error: 1.1543 - y2_output_root_mean_squared_error: 1.8605 - val_loss: 4.9744 - val_y1_output_loss: 1.3341 - val_y2_output_loss: 3.6403 - val_y1_output_root_mean_squared_error: 1.1550 - val_y2_output_root_mean_squared_error: 1.9080
# Epoch 70/500
# 62/62 [==============================] - 3s 43ms/step - loss: 9.1337 - y1_output_loss: 2.8686 - y2_output_loss: 6.2651 - y1_output_root_mean_squared_error: 1.6937 - y2_output_root_mean_squared_error: 2.5030 - val_loss: 7.5975 - val_y1_output_loss: 1.1863 - val_y2_output_loss: 6.4112 - val_y1_output_root_mean_squared_error: 1.0892 - val_y2_output_root_mean_squared_error: 2.5320
# Epoch 71/500
# 62/62 [==============================] - 3s 45ms/step - loss: 4.0274 - y1_output_loss: 1.1215 - y2_output_loss: 2.9059 - y1_output_root_mean_squared_error: 1.0590 - y2_output_root_mean_squared_error: 1.7047 - val_loss: 7.3119 - val_y1_output_loss: 2.1303 - val_y2_output_loss: 5.1816 - val_y1_output_root_mean_squared_error: 1.4596 - val_y2_output_root_mean_squared_error: 2.2763
# Epoch 72/500
# 62/62 [==============================] - 3s 44ms/step - loss: 5.1269 - y1_output_loss: 1.5129 - y2_output_loss: 3.6140 - y1_output_root_mean_squared_error: 1.2300 - y2_output_root_mean_squared_error: 1.9011 - val_loss: 15.8182 - val_y1_output_loss: 5.0746 - val_y2_output_loss: 10.7437 - val_y1_output_root_mean_squared_error: 2.2527 - val_y2_output_root_mean_squared_error: 3.2778
# Epoch 73/500
# 62/62 [==============================] - 3s 50ms/step - loss: 8.0548 - y1_output_loss: 2.2368 - y2_output_loss: 5.8180 - y1_output_root_mean_squared_error: 1.4956 - y2_output_root_mean_squared_error: 2.4120 - val_loss: 4.6694 - val_y1_output_loss: 1.1242 - val_y2_output_loss: 3.5452 - val_y1_output_root_mean_squared_error: 1.0603 - val_y2_output_root_mean_squared_error: 1.8829
# Epoch 74/500
# 62/62 [==============================] - 3s 50ms/step - loss: 4.6117 - y1_output_loss: 1.2898 - y2_output_loss: 3.3219 - y1_output_root_mean_squared_error: 1.1357 - y2_output_root_mean_squared_error: 1.8226 - val_loss: 15.3231 - val_y1_output_loss: 2.1324 - val_y2_output_loss: 13.1908 - val_y1_output_root_mean_squared_error: 1.4603 - val_y2_output_root_mean_squared_error: 3.6319
# Epoch 75/500
# 62/62 [==============================] - 3s 49ms/step - loss: 9.0875 - y1_output_loss: 2.7127 - y2_output_loss: 6.3748 - y1_output_root_mean_squared_error: 1.6470 - y2_output_root_mean_squared_error: 2.5248 - val_loss: 4.6924 - val_y1_output_loss: 0.8921 - val_y2_output_loss: 3.8003 - val_y1_output_root_mean_squared_error: 0.9445 - val_y2_output_root_mean_squared_error: 1.9494
# Epoch 76/500
# 62/62 [==============================] - 1s 15ms/step - loss: 4.5080 - y1_output_loss: 1.0701 - y2_output_loss: 3.4379 - y1_output_root_mean_squared_error: 1.0345 - y2_output_root_mean_squared_error: 1.8541 - val_loss: 4.7895 - val_y1_output_loss: 1.1474 - val_y2_output_loss: 3.6421 - val_y1_output_root_mean_squared_error: 1.0711 - val_y2_output_root_mean_squared_error: 1.9084
# Epoch 77/500
# 62/62 [==============================] - 3s 44ms/step - loss: 3.9888 - y1_output_loss: 1.0780 - y2_output_loss: 2.9107 - y1_output_root_mean_squared_error: 1.0383 - y2_output_root_mean_squared_error: 1.7061 - val_loss: 7.8123 - val_y1_output_loss: 1.7469 - val_y2_output_loss: 6.0654 - val_y1_output_root_mean_squared_error: 1.3217 - val_y2_output_root_mean_squared_error: 2.4628
# Epoch 78/500
# 62/62 [==============================] - 2s 41ms/step - loss: 4.5546 - y1_output_loss: 1.2230 - y2_output_loss: 3.3316 - y1_output_root_mean_squared_error: 1.1059 - y2_output_root_mean_squared_error: 1.8253 - val_loss: 3.8912 - val_y1_output_loss: 0.6506 - val_y2_output_loss: 3.2406 - val_y1_output_root_mean_squared_error: 0.8066 - val_y2_output_root_mean_squared_error: 1.8002
# Epoch 79/500
# 62/62 [==============================] - 3s 44ms/step - loss: 3.9909 - y1_output_loss: 1.0922 - y2_output_loss: 2.8987 - y1_output_root_mean_squared_error: 1.0451 - y2_output_root_mean_squared_error: 1.7026 - val_loss: 4.4194 - val_y1_output_loss: 1.0265 - val_y2_output_loss: 3.3928 - val_y1_output_root_mean_squared_error: 1.0132 - val_y2_output_root_mean_squared_error: 1.8420
# Epoch 80/500
# 62/62 [==============================] - 3s 47ms/step - loss: 4.7543 - y1_output_loss: 1.2421 - y2_output_loss: 3.5122 - y1_output_root_mean_squared_error: 1.1145 - y2_output_root_mean_squared_error: 1.8741 - val_loss: 4.3272 - val_y1_output_loss: 0.8269 - val_y2_output_loss: 3.5003 - val_y1_output_root_mean_squared_error: 0.9093 - val_y2_output_root_mean_squared_error: 1.8709
# Epoch 81/500
# 62/62 [==============================] - 1s 11ms/step - loss: 3.2404 - y1_output_loss: 0.8149 - y2_output_loss: 2.4255 - y1_output_root_mean_squared_error: 0.9027 - y2_output_root_mean_squared_error: 1.5574 - val_loss: 6.2382 - val_y1_output_loss: 0.9740 - val_y2_output_loss: 5.2641 - val_y1_output_root_mean_squared_error: 0.9869 - val_y2_output_root_mean_squared_error: 2.2944
# Epoch 82/500
# 62/62 [==============================] - 3s 14ms/step - loss: 4.4160 - y1_output_loss: 1.1917 - y2_output_loss: 3.2243 - y1_output_root_mean_squared_error: 1.0917 - y2_output_root_mean_squared_error: 1.7956 - val_loss: 9.2974 - val_y1_output_loss: 1.7930 - val_y2_output_loss: 7.5044 - val_y1_output_root_mean_squared_error: 1.3390 - val_y2_output_root_mean_squared_error: 2.7394
# Epoch 83/500
# 62/62 [==============================] - 3s 47ms/step - loss: 4.3974 - y1_output_loss: 1.1855 - y2_output_loss: 3.2119 - y1_output_root_mean_squared_error: 1.0888 - y2_output_root_mean_squared_error: 1.7922 - val_loss: 3.5878 - val_y1_output_loss: 0.5736 - val_y2_output_loss: 3.0142 - val_y1_output_root_mean_squared_error: 0.7574 - val_y2_output_root_mean_squared_error: 1.7361
# Epoch 84/500
# 62/62 [==============================] - 3s 43ms/step - loss: 5.2516 - y1_output_loss: 1.2285 - y2_output_loss: 4.0231 - y1_output_root_mean_squared_error: 1.1084 - y2_output_root_mean_squared_error: 2.0058 - val_loss: 5.1766 - val_y1_output_loss: 1.7395 - val_y2_output_loss: 3.4371 - val_y1_output_root_mean_squared_error: 1.3189 - val_y2_output_root_mean_squared_error: 1.8539
# Epoch 85/500
# 62/62 [==============================] - 3s 46ms/step - loss: 5.1754 - y1_output_loss: 1.3451 - y2_output_loss: 3.8303 - y1_output_root_mean_squared_error: 1.1598 - y2_output_root_mean_squared_error: 1.9571 - val_loss: 5.9799 - val_y1_output_loss: 1.2858 - val_y2_output_loss: 4.6941 - val_y1_output_root_mean_squared_error: 1.1339 - val_y2_output_root_mean_squared_error: 2.1666
# Epoch 86/500
# 62/62 [==============================] - 1s 12ms/step - loss: 16.6295 - y1_output_loss: 5.2606 - y2_output_loss: 11.3689 - y1_output_root_mean_squared_error: 2.2936 - y2_output_root_mean_squared_error: 3.3718 - val_loss: 17.2345 - val_y1_output_loss: 5.1126 - val_y2_output_loss: 12.1220 - val_y1_output_root_mean_squared_error: 2.2611 - val_y2_output_root_mean_squared_error: 3.4817
# Epoch 87/500
# 62/62 [==============================] - 3s 43ms/step - loss: 3.8872 - y1_output_loss: 1.0110 - y2_output_loss: 2.8762 - y1_output_root_mean_squared_error: 1.0055 - y2_output_root_mean_squared_error: 1.6959 - val_loss: 4.9272 - val_y1_output_loss: 0.8214 - val_y2_output_loss: 4.1058 - val_y1_output_root_mean_squared_error: 0.9063 - val_y2_output_root_mean_squared_error: 2.0263
# Epoch 88/500
# 62/62 [==============================] - 3s 44ms/step - loss: 3.9201 - y1_output_loss: 0.9918 - y2_output_loss: 2.9283 - y1_output_root_mean_squared_error: 0.9959 - y2_output_root_mean_squared_error: 1.7112 - val_loss: 5.7136 - val_y1_output_loss: 1.6017 - val_y2_output_loss: 4.1118 - val_y1_output_root_mean_squared_error: 1.2656 - val_y2_output_root_mean_squared_error: 2.0278
# Epoch 89/500
# 62/62 [==============================] - 3s 45ms/step - loss: 2.8996 - y1_output_loss: 0.7415 - y2_output_loss: 2.1581 - y1_output_root_mean_squared_error: 0.8611 - y2_output_root_mean_squared_error: 1.4691 - val_loss: 3.9033 - val_y1_output_loss: 0.5189 - val_y2_output_loss: 3.3844 - val_y1_output_root_mean_squared_error: 0.7203 - val_y2_output_root_mean_squared_error: 1.8397
# Epoch 90/500
# 62/62 [==============================] - 1s 15ms/step - loss: 3.0463 - y1_output_loss: 0.7505 - y2_output_loss: 2.2958 - y1_output_root_mean_squared_error: 0.8663 - y2_output_root_mean_squared_error: 1.5152 - val_loss: 8.7322 - val_y1_output_loss: 1.7492 - val_y2_output_loss: 6.9830 - val_y1_output_root_mean_squared_error: 1.3226 - val_y2_output_root_mean_squared_error: 2.6425
# Epoch 91/500
# 62/62 [==============================] - 1s 13ms/step - loss: 2.8614 - y1_output_loss: 0.7553 - y2_output_loss: 2.1061 - y1_output_root_mean_squared_error: 0.8691 - y2_output_root_mean_squared_error: 1.4512 - val_loss: 4.9555 - val_y1_output_loss: 0.6945 - val_y2_output_loss: 4.2609 - val_y1_output_root_mean_squared_error: 0.8334 - val_y2_output_root_mean_squared_error: 2.0642
# Epoch 92/500
# 62/62 [==============================] - 3s 41ms/step - loss: 4.0472 - y1_output_loss: 1.1370 - y2_output_loss: 2.9102 - y1_output_root_mean_squared_error: 1.0663 - y2_output_root_mean_squared_error: 1.7059 - val_loss: 3.3493 - val_y1_output_loss: 0.6192 - val_y2_output_loss: 2.7300 - val_y1_output_root_mean_squared_error: 0.7869 - val_y2_output_root_mean_squared_error: 1.6523
# Epoch 93/500
# 62/62 [==============================] - 3s 43ms/step - loss: 3.2223 - y1_output_loss: 0.8494 - y2_output_loss: 2.3729 - y1_output_root_mean_squared_error: 0.9216 - y2_output_root_mean_squared_error: 1.5404 - val_loss: 3.6490 - val_y1_output_loss: 0.6032 - val_y2_output_loss: 3.0458 - val_y1_output_root_mean_squared_error: 0.7767 - val_y2_output_root_mean_squared_error: 1.7452
# Epoch 94/500
# 62/62 [==============================] - 3s 42ms/step - loss: 4.5784 - y1_output_loss: 1.2602 - y2_output_loss: 3.3182 - y1_output_root_mean_squared_error: 1.1226 - y2_output_root_mean_squared_error: 1.8216 - val_loss: 3.2871 - val_y1_output_loss: 0.4817 - val_y2_output_loss: 2.8054 - val_y1_output_root_mean_squared_error: 0.6941 - val_y2_output_root_mean_squared_error: 1.6749
# Epoch 95/500
# 62/62 [==============================] - 1s 12ms/step - loss: 3.3902 - y1_output_loss: 0.9253 - y2_output_loss: 2.4648 - y1_output_root_mean_squared_error: 0.9619 - y2_output_root_mean_squared_error: 1.5700 - val_loss: 3.0007 - val_y1_output_loss: 0.5272 - val_y2_output_loss: 2.4735 - val_y1_output_root_mean_squared_error: 0.7261 - val_y2_output_root_mean_squared_error: 1.5728
# Epoch 96/500
# 62/62 [==============================] - 3s 46ms/step - loss: 2.9843 - y1_output_loss: 0.7971 - y2_output_loss: 2.1871 - y1_output_root_mean_squared_error: 0.8928 - y2_output_root_mean_squared_error: 1.4789 - val_loss: 4.1325 - val_y1_output_loss: 0.9438 - val_y2_output_loss: 3.1887 - val_y1_output_root_mean_squared_error: 0.9715 - val_y2_output_root_mean_squared_error: 1.7857
# Epoch 97/500
# 62/62 [==============================] - 3s 44ms/step - loss: 3.6036 - y1_output_loss: 0.9615 - y2_output_loss: 2.6420 - y1_output_root_mean_squared_error: 0.9806 - y2_output_root_mean_squared_error: 1.6254 - val_loss: 3.1983 - val_y1_output_loss: 0.6606 - val_y2_output_loss: 2.5377 - val_y1_output_root_mean_squared_error: 0.8128 - val_y2_output_root_mean_squared_error: 1.5930
# Epoch 98/500
# 62/62 [==============================] - 3s 46ms/step - loss: 2.9484 - y1_output_loss: 0.7843 - y2_output_loss: 2.1641 - y1_output_root_mean_squared_error: 0.8856 - y2_output_root_mean_squared_error: 1.4711 - val_loss: 2.7792 - val_y1_output_loss: 0.4782 - val_y2_output_loss: 2.3010 - val_y1_output_root_mean_squared_error: 0.6915 - val_y2_output_root_mean_squared_error: 1.5169
# Epoch 99/500
# 62/62 [==============================] - 3s 49ms/step - loss: 3.3466 - y1_output_loss: 0.8959 - y2_output_loss: 2.4506 - y1_output_root_mean_squared_error: 0.9465 - y2_output_root_mean_squared_error: 1.5654 - val_loss: 4.1828 - val_y1_output_loss: 0.6361 - val_y2_output_loss: 3.5467 - val_y1_output_root_mean_squared_error: 0.7976 - val_y2_output_root_mean_squared_error: 1.8833
# Epoch 100/500
# 62/62 [==============================] - 3s 52ms/step - loss: 3.4130 - y1_output_loss: 0.8681 - y2_output_loss: 2.5449 - y1_output_root_mean_squared_error: 0.9317 - y2_output_root_mean_squared_error: 1.5953 - val_loss: 4.5456 - val_y1_output_loss: 0.5678 - val_y2_output_loss: 3.9778 - val_y1_output_root_mean_squared_error: 0.7535 - val_y2_output_root_mean_squared_error: 1.9944
# Epoch 101/500
# 62/62 [==============================] - 3s 52ms/step - loss: 3.0465 - y1_output_loss: 0.7652 - y2_output_loss: 2.2813 - y1_output_root_mean_squared_error: 0.8748 - y2_output_root_mean_squared_error: 1.5104 - val_loss: 79.0096 - val_y1_output_loss: 31.4433 - val_y2_output_loss: 47.5663 - val_y1_output_root_mean_squared_error: 5.6074 - val_y2_output_root_mean_squared_error: 6.8968
# Epoch 102/500
# 62/62 [==============================] - 3s 52ms/step - loss: 6.6306 - y1_output_loss: 2.1459 - y2_output_loss: 4.4847 - y1_output_root_mean_squared_error: 1.4649 - y2_output_root_mean_squared_error: 2.1177 - val_loss: 10.6979 - val_y1_output_loss: 3.4092 - val_y2_output_loss: 7.2887 - val_y1_output_root_mean_squared_error: 1.8464 - val_y2_output_root_mean_squared_error: 2.6998
# Epoch 103/500
# 62/62 [==============================] - 3s 50ms/step - loss: 3.4255 - y1_output_loss: 0.9281 - y2_output_loss: 2.4975 - y1_output_root_mean_squared_error: 0.9634 - y2_output_root_mean_squared_error: 1.5803 - val_loss: 3.1428 - val_y1_output_loss: 0.5442 - val_y2_output_loss: 2.5987 - val_y1_output_root_mean_squared_error: 0.7377 - val_y2_output_root_mean_squared_error: 1.6120
# Epoch 104/500
# 62/62 [==============================] - 3s 46ms/step - loss: 2.9126 - y1_output_loss: 0.8013 - y2_output_loss: 2.1113 - y1_output_root_mean_squared_error: 0.8952 - y2_output_root_mean_squared_error: 1.4530 - val_loss: 2.9702 - val_y1_output_loss: 0.5734 - val_y2_output_loss: 2.3968 - val_y1_output_root_mean_squared_error: 0.7572 - val_y2_output_root_mean_squared_error: 1.5481
# Epoch 105/500
# 62/62 [==============================] - 3s 45ms/step - loss: 2.6297 - y1_output_loss: 0.5685 - y2_output_loss: 2.0612 - y1_output_root_mean_squared_error: 0.7540 - y2_output_root_mean_squared_error: 1.4357 - val_loss: 2.7659 - val_y1_output_loss: 0.4792 - val_y2_output_loss: 2.2867 - val_y1_output_root_mean_squared_error: 0.6923 - val_y2_output_root_mean_squared_error: 1.5122
# Epoch 106/500
# 62/62 [==============================] - 3s 44ms/step - loss: 2.8366 - y1_output_loss: 0.7911 - y2_output_loss: 2.0455 - y1_output_root_mean_squared_error: 0.8895 - y2_output_root_mean_squared_error: 1.4302 - val_loss: 3.0711 - val_y1_output_loss: 0.5870 - val_y2_output_loss: 2.4842 - val_y1_output_root_mean_squared_error: 0.7661 - val_y2_output_root_mean_squared_error: 1.5761
# Epoch 107/500
# 62/62 [==============================] - 1s 14ms/step - loss: 3.5877 - y1_output_loss: 0.9763 - y2_output_loss: 2.6115 - y1_output_root_mean_squared_error: 0.9881 - y2_output_root_mean_squared_error: 1.6160 - val_loss: 3.1706 - val_y1_output_loss: 0.6127 - val_y2_output_loss: 2.5579 - val_y1_output_root_mean_squared_error: 0.7828 - val_y2_output_root_mean_squared_error: 1.5994
# Epoch 108/500
# 62/62 [==============================] - 3s 43ms/step - loss: 2.6354 - y1_output_loss: 0.6956 - y2_output_loss: 1.9398 - y1_output_root_mean_squared_error: 0.8340 - y2_output_root_mean_squared_error: 1.3928 - val_loss: 6.0084 - val_y1_output_loss: 1.5544 - val_y2_output_loss: 4.4540 - val_y1_output_root_mean_squared_error: 1.2468 - val_y2_output_root_mean_squared_error: 2.1105
# Epoch 109/500
# 62/62 [==============================] - 3s 44ms/step - loss: 2.2987 - y1_output_loss: 0.5911 - y2_output_loss: 1.7076 - y1_output_root_mean_squared_error: 0.7688 - y2_output_root_mean_squared_error: 1.3068 - val_loss: 24.2100 - val_y1_output_loss: 6.9596 - val_y2_output_loss: 17.2504 - val_y1_output_root_mean_squared_error: 2.6381 - val_y2_output_root_mean_squared_error: 4.1534
# Epoch 110/500
# 62/62 [==============================] - 1s 12ms/step - loss: 3.8659 - y1_output_loss: 0.9155 - y2_output_loss: 2.9504 - y1_output_root_mean_squared_error: 0.9568 - y2_output_root_mean_squared_error: 1.7177 - val_loss: 13.5046 - val_y1_output_loss: 1.5600 - val_y2_output_loss: 11.9445 - val_y1_output_root_mean_squared_error: 1.2490 - val_y2_output_root_mean_squared_error: 3.4561
# Epoch 111/500
# 62/62 [==============================] - 3s 43ms/step - loss: 11.9567 - y1_output_loss: 3.6907 - y2_output_loss: 8.2661 - y1_output_root_mean_squared_error: 1.9211 - y2_output_root_mean_squared_error: 2.8751 - val_loss: 3.3077 - val_y1_output_loss: 0.5095 - val_y2_output_loss: 2.7982 - val_y1_output_root_mean_squared_error: 0.7138 - val_y2_output_root_mean_squared_error: 1.6728
# Epoch 112/500
# 62/62 [==============================] - 3s 46ms/step - loss: 3.4040 - y1_output_loss: 0.8909 - y2_output_loss: 2.5131 - y1_output_root_mean_squared_error: 0.9439 - y2_output_root_mean_squared_error: 1.5853 - val_loss: 3.6262 - val_y1_output_loss: 0.4009 - val_y2_output_loss: 3.2252 - val_y1_output_root_mean_squared_error: 0.6332 - val_y2_output_root_mean_squared_error: 1.7959
# Epoch 113/500
# 62/62 [==============================] - 3s 43ms/step - loss: 2.3562 - y1_output_loss: 0.5519 - y2_output_loss: 1.8043 - y1_output_root_mean_squared_error: 0.7429 - y2_output_root_mean_squared_error: 1.3432 - val_loss: 3.0046 - val_y1_output_loss: 0.4449 - val_y2_output_loss: 2.5597 - val_y1_output_root_mean_squared_error: 0.6670 - val_y2_output_root_mean_squared_error: 1.5999
# Epoch 114/500
# 62/62 [==============================] - 3s 45ms/step - loss: 2.1141 - y1_output_loss: 0.5226 - y2_output_loss: 1.5915 - y1_output_root_mean_squared_error: 0.7229 - y2_output_root_mean_squared_error: 1.2616 - val_loss: 2.4738 - val_y1_output_loss: 0.4936 - val_y2_output_loss: 1.9802 - val_y1_output_root_mean_squared_error: 0.7026 - val_y2_output_root_mean_squared_error: 1.4072
# Epoch 115/500
# 62/62 [==============================] - 1s 12ms/step - loss: 2.1850 - y1_output_loss: 0.5661 - y2_output_loss: 1.6190 - y1_output_root_mean_squared_error: 0.7524 - y2_output_root_mean_squared_error: 1.2724 - val_loss: 3.1866 - val_y1_output_loss: 0.7280 - val_y2_output_loss: 2.4587 - val_y1_output_root_mean_squared_error: 0.8532 - val_y2_output_root_mean_squared_error: 1.5680
# Epoch 116/500
# 62/62 [==============================] - 3s 44ms/step - loss: 10.7047 - y1_output_loss: 3.6930 - y2_output_loss: 7.0116 - y1_output_root_mean_squared_error: 1.9217 - y2_output_root_mean_squared_error: 2.6480 - val_loss: 21.2789 - val_y1_output_loss: 3.9490 - val_y2_output_loss: 17.3300 - val_y1_output_root_mean_squared_error: 1.9872 - val_y2_output_root_mean_squared_error: 4.1629
# Epoch 117/500
# 62/62 [==============================] - 3s 43ms/step - loss: 4.9201 - y1_output_loss: 1.5997 - y2_output_loss: 3.3204 - y1_output_root_mean_squared_error: 1.2648 - y2_output_root_mean_squared_error: 1.8222 - val_loss: 5.8345 - val_y1_output_loss: 1.9797 - val_y2_output_loss: 3.8548 - val_y1_output_root_mean_squared_error: 1.4070 - val_y2_output_root_mean_squared_error: 1.9634
# Epoch 118/500
# 62/62 [==============================] - 3s 44ms/step - loss: 2.2469 - y1_output_loss: 0.5076 - y2_output_loss: 1.7392 - y1_output_root_mean_squared_error: 0.7125 - y2_output_root_mean_squared_error: 1.3188 - val_loss: 3.0687 - val_y1_output_loss: 0.7005 - val_y2_output_loss: 2.3683 - val_y1_output_root_mean_squared_error: 0.8369 - val_y2_output_root_mean_squared_error: 1.5389
# Epoch 119/500
# 62/62 [==============================] - 1s 13ms/step - loss: 2.1618 - y1_output_loss: 0.5212 - y2_output_loss: 1.6406 - y1_output_root_mean_squared_error: 0.7219 - y2_output_root_mean_squared_error: 1.2809 - val_loss: 4.5309 - val_y1_output_loss: 1.1456 - val_y2_output_loss: 3.3853 - val_y1_output_root_mean_squared_error: 1.0703 - val_y2_output_root_mean_squared_error: 1.8399
# Epoch 120/500
# 62/62 [==============================] - 3s 44ms/step - loss: 2.4702 - y1_output_loss: 0.5984 - y2_output_loss: 1.8718 - y1_output_root_mean_squared_error: 0.7736 - y2_output_root_mean_squared_error: 1.3681 - val_loss: 2.5624 - val_y1_output_loss: 0.4939 - val_y2_output_loss: 2.0685 - val_y1_output_root_mean_squared_error: 0.7027 - val_y2_output_root_mean_squared_error: 1.4382
# Epoch 121/500
# 62/62 [==============================] - 3s 45ms/step - loss: 2.0757 - y1_output_loss: 0.4634 - y2_output_loss: 1.6123 - y1_output_root_mean_squared_error: 0.6808 - y2_output_root_mean_squared_error: 1.2697 - val_loss: 5.6487 - val_y1_output_loss: 1.4940 - val_y2_output_loss: 4.1547 - val_y1_output_root_mean_squared_error: 1.2223 - val_y2_output_root_mean_squared_error: 2.0383
# Epoch 122/500
# ...
# Epoch 461/500
# 62/62 [==============================] - 1s 12ms/step - loss: 0.4048 - y1_output_loss: 0.1314 - y2_output_loss: 0.2734 - y1_output_root_mean_squared_error: 0.3625 - y2_output_root_mean_squared_error: 0.5229 - val_loss: 1.1542 - val_y1_output_loss: 0.1892 - val_y2_output_loss: 0.9650 - val_y1_output_root_mean_squared_error: 0.4350 - val_y2_output_root_mean_squared_error: 0.9823
# Epoch 462/500
# 62/62 [==============================] - 1s 14ms/step - loss: 0.5138 - y1_output_loss: 0.1342 - y2_output_loss: 0.3796 - y1_output_root_mean_squared_error: 0.3663 - y2_output_root_mean_squared_error: 0.6161 - val_loss: 1.1472 - val_y1_output_loss: 0.3069 - val_y2_output_loss: 0.8402 - val_y1_output_root_mean_squared_error: 0.5540 - val_y2_output_root_mean_squared_error: 0.9166
# Epoch 463/500
# 62/62 [==============================] - 1s 10ms/step - loss: 0.3897 - y1_output_loss: 0.1193 - y2_output_loss: 0.2704 - y1_output_root_mean_squared_error: 0.3454 - y2_output_root_mean_squared_error: 0.5200 - val_loss: 0.9418 - val_y1_output_loss: 0.1876 - val_y2_output_loss: 0.7542 - val_y1_output_root_mean_squared_error: 0.4331 - val_y2_output_root_mean_squared_error: 0.8684
# Epoch 464/500
# 62/62 [==============================] - 1s 10ms/step - loss: 0.3846 - y1_output_loss: 0.1149 - y2_output_loss: 0.2697 - y1_output_root_mean_squared_error: 0.3389 - y2_output_root_mean_squared_error: 0.5194 - val_loss: 0.9085 - val_y1_output_loss: 0.1887 - val_y2_output_loss: 0.7198 - val_y1_output_root_mean_squared_error: 0.4344 - val_y2_output_root_mean_squared_error: 0.8484
# Epoch 465/500
# 62/62 [==============================] - 1s 23ms/step - loss: 0.8064 - y1_output_loss: 0.1874 - y2_output_loss: 0.6191 - y1_output_root_mean_squared_error: 0.4329 - y2_output_root_mean_squared_error: 0.7868 - val_loss: 1.0499 - val_y1_output_loss: 0.2053 - val_y2_output_loss: 0.8446 - val_y1_output_root_mean_squared_error: 0.4531 - val_y2_output_root_mean_squared_error: 0.9190
# Epoch 466/500
# 62/62 [==============================] - 2s 26ms/step - loss: 0.3862 - y1_output_loss: 0.1261 - y2_output_loss: 0.2600 - y1_output_root_mean_squared_error: 0.3552 - y2_output_root_mean_squared_error: 0.5099 - val_loss: 0.9690 - val_y1_output_loss: 0.2134 - val_y2_output_loss: 0.7556 - val_y1_output_root_mean_squared_error: 0.4620 - val_y2_output_root_mean_squared_error: 0.8692
# Epoch 467/500
# 62/62 [==============================] - 2s 29ms/step - loss: 0.4249 - y1_output_loss: 0.1334 - y2_output_loss: 0.2916 - y1_output_root_mean_squared_error: 0.3652 - y2_output_root_mean_squared_error: 0.5400 - val_loss: 1.3357 - val_y1_output_loss: 0.2693 - val_y2_output_loss: 1.0664 - val_y1_output_root_mean_squared_error: 0.5189 - val_y2_output_root_mean_squared_error: 1.0327
# Epoch 468/500
# 62/62 [==============================] - 1s 19ms/step - loss: 0.3629 - y1_output_loss: 0.1329 - y2_output_loss: 0.2301 - y1_output_root_mean_squared_error: 0.3645 - y2_output_root_mean_squared_error: 0.4796 - val_loss: 0.9272 - val_y1_output_loss: 0.1927 - val_y2_output_loss: 0.7345 - val_y1_output_root_mean_squared_error: 0.4390 - val_y2_output_root_mean_squared_error: 0.8570
# Epoch 469/500
# 62/62 [==============================] - 1s 17ms/step - loss: 0.3848 - y1_output_loss: 0.1271 - y2_output_loss: 0.2577 - y1_output_root_mean_squared_error: 0.3564 - y2_output_root_mean_squared_error: 0.5077 - val_loss: 0.8686 - val_y1_output_loss: 0.1890 - val_y2_output_loss: 0.6796 - val_y1_output_root_mean_squared_error: 0.4348 - val_y2_output_root_mean_squared_error: 0.8244
# Epoch 470/500
# 62/62 [==============================] - 1s 17ms/step - loss: 0.4423 - y1_output_loss: 0.1406 - y2_output_loss: 0.3016 - y1_output_root_mean_squared_error: 0.3750 - y2_output_root_mean_squared_error: 0.5492 - val_loss: 1.2732 - val_y1_output_loss: 0.2488 - val_y2_output_loss: 1.0245 - val_y1_output_root_mean_squared_error: 0.4988 - val_y2_output_root_mean_squared_error: 1.0122
# Epoch 471/500
# 62/62 [==============================] - 1s 13ms/step - loss: 0.4289 - y1_output_loss: 0.1318 - y2_output_loss: 0.2972 - y1_output_root_mean_squared_error: 0.3630 - y2_output_root_mean_squared_error: 0.5451 - val_loss: 0.9969 - val_y1_output_loss: 0.1891 - val_y2_output_loss: 0.8078 - val_y1_output_root_mean_squared_error: 0.4348 - val_y2_output_root_mean_squared_error: 0.8988
# Epoch 472/500
# 62/62 [==============================] - 1s 11ms/step - loss: 0.4678 - y1_output_loss: 0.1466 - y2_output_loss: 0.3211 - y1_output_root_mean_squared_error: 0.3829 - y2_output_root_mean_squared_error: 0.5667 - val_loss: 0.9838 - val_y1_output_loss: 0.1932 - val_y2_output_loss: 0.7906 - val_y1_output_root_mean_squared_error: 0.4395 - val_y2_output_root_mean_squared_error: 0.8892
# Epoch 473/500
# 62/62 [==============================] - 1s 14ms/step - loss: 0.3849 - y1_output_loss: 0.1433 - y2_output_loss: 0.2416 - y1_output_root_mean_squared_error: 0.3785 - y2_output_root_mean_squared_error: 0.4915 - val_loss: 1.0875 - val_y1_output_loss: 0.1848 - val_y2_output_loss: 0.9027 - val_y1_output_root_mean_squared_error: 0.4298 - val_y2_output_root_mean_squared_error: 0.9501
# Epoch 474/500
# 62/62 [==============================] - 1s 12ms/step - loss: 0.4653 - y1_output_loss: 0.1328 - y2_output_loss: 0.3325 - y1_output_root_mean_squared_error: 0.3644 - y2_output_root_mean_squared_error: 0.5767 - val_loss: 1.0630 - val_y1_output_loss: 0.2011 - val_y2_output_loss: 0.8619 - val_y1_output_root_mean_squared_error: 0.4485 - val_y2_output_root_mean_squared_error: 0.9284
# Epoch 475/500
# 62/62 [==============================] - 1s 11ms/step - loss: 0.3189 - y1_output_loss: 0.1188 - y2_output_loss: 0.2002 - y1_output_root_mean_squared_error: 0.3446 - y2_output_root_mean_squared_error: 0.4474 - val_loss: 0.9401 - val_y1_output_loss: 0.1712 - val_y2_output_loss: 0.7689 - val_y1_output_root_mean_squared_error: 0.4138 - val_y2_output_root_mean_squared_error: 0.8769
# Epoch 476/500
# 62/62 [==============================] - 1s 13ms/step - loss: 0.3436 - y1_output_loss: 0.1113 - y2_output_loss: 0.2323 - y1_output_root_mean_squared_error: 0.3337 - y2_output_root_mean_squared_error: 0.4820 - val_loss: 1.2358 - val_y1_output_loss: 0.2762 - val_y2_output_loss: 0.9597 - val_y1_output_root_mean_squared_error: 0.5255 - val_y2_output_root_mean_squared_error: 0.9796
# Epoch 477/500
# 62/62 [==============================] - 1s 11ms/step - loss: 0.3449 - y1_output_loss: 0.1203 - y2_output_loss: 0.2246 - y1_output_root_mean_squared_error: 0.3468 - y2_output_root_mean_squared_error: 0.4739 - val_loss: 1.3169 - val_y1_output_loss: 0.1741 - val_y2_output_loss: 1.1428 - val_y1_output_root_mean_squared_error: 0.4173 - val_y2_output_root_mean_squared_error: 1.0690
# Epoch 478/500
# 62/62 [==============================] - 1s 11ms/step - loss: 0.4276 - y1_output_loss: 0.1228 - y2_output_loss: 0.3048 - y1_output_root_mean_squared_error: 0.3504 - y2_output_root_mean_squared_error: 0.5521 - val_loss: 0.9368 - val_y1_output_loss: 0.1814 - val_y2_output_loss: 0.7554 - val_y1_output_root_mean_squared_error: 0.4259 - val_y2_output_root_mean_squared_error: 0.8691
# Epoch 479/500
# 62/62 [==============================] - 1s 12ms/step - loss: 0.3814 - y1_output_loss: 0.1167 - y2_output_loss: 0.2647 - y1_output_root_mean_squared_error: 0.3416 - y2_output_root_mean_squared_error: 0.5145 - val_loss: 3.6211 - val_y1_output_loss: 0.3642 - val_y2_output_loss: 3.2569 - val_y1_output_root_mean_squared_error: 0.6035 - val_y2_output_root_mean_squared_error: 1.8047
# Epoch 480/500
# 62/62 [==============================] - 1s 12ms/step - loss: 0.4795 - y1_output_loss: 0.1332 - y2_output_loss: 0.3463 - y1_output_root_mean_squared_error: 0.3650 - y2_output_root_mean_squared_error: 0.5885 - val_loss: 1.8966 - val_y1_output_loss: 0.2423 - val_y2_output_loss: 1.6543 - val_y1_output_root_mean_squared_error: 0.4923 - val_y2_output_root_mean_squared_error: 1.2862
# Epoch 481/500
# 62/62 [==============================] - 1s 13ms/step - loss: 0.3540 - y1_output_loss: 0.1216 - y2_output_loss: 0.2324 - y1_output_root_mean_squared_error: 0.3487 - y2_output_root_mean_squared_error: 0.4821 - val_loss: 0.9280 - val_y1_output_loss: 0.1631 - val_y2_output_loss: 0.7649 - val_y1_output_root_mean_squared_error: 0.4038 - val_y2_output_root_mean_squared_error: 0.8746
# Epoch 482/500
# 62/62 [==============================] - 1s 12ms/step - loss: 0.4455 - y1_output_loss: 0.1313 - y2_output_loss: 0.3142 - y1_output_root_mean_squared_error: 0.3623 - y2_output_root_mean_squared_error: 0.5605 - val_loss: 1.0195 - val_y1_output_loss: 0.1795 - val_y2_output_loss: 0.8400 - val_y1_output_root_mean_squared_error: 0.4236 - val_y2_output_root_mean_squared_error: 0.9165
# Epoch 483/500
# 62/62 [==============================] - 1s 12ms/step - loss: 0.4142 - y1_output_loss: 0.1290 - y2_output_loss: 0.2852 - y1_output_root_mean_squared_error: 0.3592 - y2_output_root_mean_squared_error: 0.5340 - val_loss: 1.6294 - val_y1_output_loss: 0.2371 - val_y2_output_loss: 1.3923 - val_y1_output_root_mean_squared_error: 0.4869 - val_y2_output_root_mean_squared_error: 1.1800
# Epoch 484/500
# 62/62 [==============================] - 1s 10ms/step - loss: 0.3782 - y1_output_loss: 0.1223 - y2_output_loss: 0.2559 - y1_output_root_mean_squared_error: 0.3497 - y2_output_root_mean_squared_error: 0.5058 - val_loss: 0.9692 - val_y1_output_loss: 0.1901 - val_y2_output_loss: 0.7791 - val_y1_output_root_mean_squared_error: 0.4360 - val_y2_output_root_mean_squared_error: 0.8827
# Epoch 485/500
# 62/62 [==============================] - 1s 11ms/step - loss: 0.4290 - y1_output_loss: 0.1490 - y2_output_loss: 0.2800 - y1_output_root_mean_squared_error: 0.3860 - y2_output_root_mean_squared_error: 0.5291 - val_loss: 0.9170 - val_y1_output_loss: 0.1914 - val_y2_output_loss: 0.7256 - val_y1_output_root_mean_squared_error: 0.4375 - val_y2_output_root_mean_squared_error: 0.8518
# Epoch 486/500
# 62/62 [==============================] - 1s 12ms/step - loss: 0.3399 - y1_output_loss: 0.1219 - y2_output_loss: 0.2180 - y1_output_root_mean_squared_error: 0.3491 - y2_output_root_mean_squared_error: 0.4669 - val_loss: 1.1710 - val_y1_output_loss: 0.2968 - val_y2_output_loss: 0.8742 - val_y1_output_root_mean_squared_error: 0.5448 - val_y2_output_root_mean_squared_error: 0.9350
# Epoch 487/500
# 62/62 [==============================] - 1s 13ms/step - loss: 0.4149 - y1_output_loss: 0.1197 - y2_output_loss: 0.2952 - y1_output_root_mean_squared_error: 0.3460 - y2_output_root_mean_squared_error: 0.5433 - val_loss: 1.2150 - val_y1_output_loss: 0.2509 - val_y2_output_loss: 0.9641 - val_y1_output_root_mean_squared_error: 0.5009 - val_y2_output_root_mean_squared_error: 0.9819
# Epoch 488/500
# 62/62 [==============================] - 1s 11ms/step - loss: 0.5923 - y1_output_loss: 0.1483 - y2_output_loss: 0.4441 - y1_output_root_mean_squared_error: 0.3850 - y2_output_root_mean_squared_error: 0.6664 - val_loss: 1.1947 - val_y1_output_loss: 0.2373 - val_y2_output_loss: 0.9574 - val_y1_output_root_mean_squared_error: 0.4871 - val_y2_output_root_mean_squared_error: 0.9785
# Epoch 489/500
# 62/62 [==============================] - 1s 14ms/step - loss: 0.3930 - y1_output_loss: 0.1411 - y2_output_loss: 0.2519 - y1_output_root_mean_squared_error: 0.3756 - y2_output_root_mean_squared_error: 0.5019 - val_loss: 1.5214 - val_y1_output_loss: 0.1985 - val_y2_output_loss: 1.3228 - val_y1_output_root_mean_squared_error: 0.4456 - val_y2_output_root_mean_squared_error: 1.1501
# Epoch 490/500
# 62/62 [==============================] - 1s 14ms/step - loss: 0.5957 - y1_output_loss: 0.1936 - y2_output_loss: 0.4021 - y1_output_root_mean_squared_error: 0.4400 - y2_output_root_mean_squared_error: 0.6341 - val_loss: 1.0944 - val_y1_output_loss: 0.2270 - val_y2_output_loss: 0.8674 - val_y1_output_root_mean_squared_error: 0.4764 - val_y2_output_root_mean_squared_error: 0.9314
# Epoch 491/500
# 62/62 [==============================] - 1s 12ms/step - loss: 0.3490 - y1_output_loss: 0.1227 - y2_output_loss: 0.2263 - y1_output_root_mean_squared_error: 0.3502 - y2_output_root_mean_squared_error: 0.4758 - val_loss: 0.9898 - val_y1_output_loss: 0.1886 - val_y2_output_loss: 0.8012 - val_y1_output_root_mean_squared_error: 0.4343 - val_y2_output_root_mean_squared_error: 0.8951
# Epoch 492/500
# 62/62 [==============================] - 1s 15ms/step - loss: 0.4111 - y1_output_loss: 0.1367 - y2_output_loss: 0.2744 - y1_output_root_mean_squared_error: 0.3698 - y2_output_root_mean_squared_error: 0.5238 - val_loss: 1.1307 - val_y1_output_loss: 0.1824 - val_y2_output_loss: 0.9482 - val_y1_output_root_mean_squared_error: 0.4271 - val_y2_output_root_mean_squared_error: 0.9738
# Epoch 493/500
# 62/62 [==============================] - 1s 13ms/step - loss: 0.4442 - y1_output_loss: 0.1260 - y2_output_loss: 0.3182 - y1_output_root_mean_squared_error: 0.3550 - y2_output_root_mean_squared_error: 0.5641 - val_loss: 1.0950 - val_y1_output_loss: 0.3560 - val_y2_output_loss: 0.7389 - val_y1_output_root_mean_squared_error: 0.5967 - val_y2_output_root_mean_squared_error: 0.8596
# Epoch 494/500
# 62/62 [==============================] - 1s 14ms/step - loss: 0.4430 - y1_output_loss: 0.1496 - y2_output_loss: 0.2934 - y1_output_root_mean_squared_error: 0.3867 - y2_output_root_mean_squared_error: 0.5417 - val_loss: 1.6503 - val_y1_output_loss: 0.2084 - val_y2_output_loss: 1.4419 - val_y1_output_root_mean_squared_error: 0.4565 - val_y2_output_root_mean_squared_error: 1.2008
# Epoch 495/500
# 62/62 [==============================] - 1s 10ms/step - loss: 0.3712 - y1_output_loss: 0.1283 - y2_output_loss: 0.2429 - y1_output_root_mean_squared_error: 0.3582 - y2_output_root_mean_squared_error: 0.4929 - val_loss: 1.0876 - val_y1_output_loss: 0.1875 - val_y2_output_loss: 0.9001 - val_y1_output_root_mean_squared_error: 0.4330 - val_y2_output_root_mean_squared_error: 0.9487
# Epoch 496/500
# 62/62 [==============================] - 1s 11ms/step - loss: 0.4165 - y1_output_loss: 0.1312 - y2_output_loss: 0.2853 - y1_output_root_mean_squared_error: 0.3622 - y2_output_root_mean_squared_error: 0.5341 - val_loss: 0.9378 - val_y1_output_loss: 0.1819 - val_y2_output_loss: 0.7559 - val_y1_output_root_mean_squared_error: 0.4266 - val_y2_output_root_mean_squared_error: 0.8694
# Epoch 497/500
# 62/62 [==============================] - 1s 13ms/step - loss: 0.3454 - y1_output_loss: 0.1167 - y2_output_loss: 0.2287 - y1_output_root_mean_squared_error: 0.3416 - y2_output_root_mean_squared_error: 0.4782 - val_loss: 0.8471 - val_y1_output_loss: 0.1756 - val_y2_output_loss: 0.6715 - val_y1_output_root_mean_squared_error: 0.4191 - val_y2_output_root_mean_squared_error: 0.8194
# Epoch 498/500
# 62/62 [==============================] - 1s 14ms/step - loss: 0.3919 - y1_output_loss: 0.1234 - y2_output_loss: 0.2685 - y1_output_root_mean_squared_error: 0.3513 - y2_output_root_mean_squared_error: 0.5181 - val_loss: 0.7963 - val_y1_output_loss: 0.1785 - val_y2_output_loss: 0.6178 - val_y1_output_root_mean_squared_error: 0.4225 - val_y2_output_root_mean_squared_error: 0.7860
# Epoch 499/500
# 62/62 [==============================] - 1s 11ms/step - loss: 0.3316 - y1_output_loss: 0.1152 - y2_output_loss: 0.2163 - y1_output_root_mean_squared_error: 0.3395 - y2_output_root_mean_squared_error: 0.4651 - val_loss: 0.8417 - val_y1_output_loss: 0.1688 - val_y2_output_loss: 0.6730 - val_y1_output_root_mean_squared_error: 0.4108 - val_y2_output_root_mean_squared_error: 0.8203
# Epoch 500/500
# 62/62 [==============================] - 1s 13ms/step - loss: 0.3388 - y1_output_loss: 0.1155 - y2_output_loss: 0.2233 - y1_output_root_mean_squared_error: 0.3398 - y2_output_root_mean_squared_error: 0.4725 - val_loss: 0.9888 - val_y1_output_loss: 0.1994 - val_y2_output_loss: 0.7894 - val_y1_output_root_mean_squared_error: 0.4465 - val_y2_output_root_mean_squared_error: 0.8885

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 5/5 [==============================] - 0s 8ms/step - loss: 0.9888 - y1_output_loss: 0.1994 - y2_output_loss: 0.7894 - y1_output_root_mean_squared_error: 0.4465 - y2_output_root_mean_squared_error: 0.8885
# Loss = 0.9888014197349548, Y1_loss = 0.199363574385643, Y1_mse = 0.4465014636516571, Y2_loss = 0.7894378304481506, Y2_mse = 0.8885031342506409

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
# Out:
# 5/5 [==============================] - 0s 4ms/step
